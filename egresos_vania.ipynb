# %%
import pandas as pd

# %% [markdown]
#  5) ¿Existen factores que explican las variaciones en las tasas de mortalidad y
#  hospitalizaciones? Considerando un análisis por región (demográfico,
#  socioeconómico, otros).

# %%
egresos = pd.read_csv("egresos/EGRESOS_2001/EGRE_DATOS_ABIERTOS_2001.csv", sep=";", encoding="latin-1")
egresos
# Out:
# C:\Users\Siwidiwi\AppData\Local\Temp\ipykernel_21380\853449519.py:1: DtypeWarning: Columns (7,9,11,15,16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   egresos = pd.read_csv("egresos/EGRESOS_2001/EGRE_DATOS_ABIERTOS_2001.csv", sep=";", encoding="latin-1")
#                          PERTENENCIA_ESTABLECIMIENTO_SALUD    SEXO GRUPO_EDAD  \
# 0        No Pertenecientes al Sistema Nacional de Servi...  HOMBRE      1 a 9
# 1        No Pertenecientes al Sistema Nacional de Servi...  HOMBRE      1 a 9
# 2        No Pertenecientes al Sistema Nacional de Servi...  HOMBRE      1 a 9
# 3        No Pertenecientes al Sistema Nacional de Servi...  HOMBRE      1 a 9
# 4        No Pertenecientes al Sistema Nacional de Servi...  HOMBRE      1 a 9
# ...                                                    ...     ...        ...
# 1566183                                                  *       *          *
# ...

# %%
años = range(2001, 2022)
dataframes = {}
for año in años:
    archivo = f"egresos/EGRESOS_{año}/EGRE_DATOS_ABIERTOS_{año}.csv"
    try:
        df = pd.read_csv(archivo, sep=";", encoding="latin-1", low_memory=False)
        dataframes[año] = df 
    except FileNotFoundError:
        print(f"Archivo no encontrado: {archivo}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 6
#       4 archivo = f"egresos/EGRESOS_{año}/EGRE_DATOS_ABIERTOS_{año}.csv"
#       5 try:
# ----> 6     df = pd.read_csv(archivo, sep=";", encoding="latin-1", low_memory=False)
#       7     dataframes[año] = df
#       8 except FileNotFoundError:
#
# ...

# %%
df_2001 = dataframes[2001]
df_2001
# Out:
#                          PERTENENCIA_ESTABLECIMIENTO_SALUD    SEXO GRUPO_EDAD  \
# 0        No Pertenecientes al Sistema Nacional de Servi...  HOMBRE      1 a 9
# 1        No Pertenecientes al Sistema Nacional de Servi...  HOMBRE      1 a 9
# 2        No Pertenecientes al Sistema Nacional de Servi...  HOMBRE      1 a 9
# 3        No Pertenecientes al Sistema Nacional de Servi...  HOMBRE      1 a 9
# 4        No Pertenecientes al Sistema Nacional de Servi...  HOMBRE      1 a 9
# ...                                                    ...     ...        ...
# 1566183                                                  *       *          *
# 1566184                                                  *       *          *
# 1566185                                                  *       *          *
# 1566186                                                  *       *          *
# 1566187                                                  *       *          *
#
# ...

# %%
df_2001.columns
# Out:
# Index(['PERTENENCIA_ESTABLECIMIENTO_SALUD', 'SEXO', 'GRUPO_EDAD', 'ETNIA',
#        'GLOSA_PAIS_ORIGEN', 'COMUNA_RESIDENCIA', 'GLOSA_COMUNA_RESIDENCIA',
#        'REGION_RESIDENCIA', 'GLOSA_REGION_RESIDENCIA', 'PREVISION',
#        'GLOSA_PREVISION', 'ANO_EGRESO', 'DIAG1', 'DIAG2', 'DIAS_ESTADA',
#        'CONDICION_EGRESO', 'INTERV_Q', 'PROCED'],
#       dtype='object')

# %%
columns_to_drop = ['ETNIA','GLOSA_PAIS_ORIGEN', 'COMUNA_RESIDENCIA', 'GLOSA_COMUNA_RESIDENCIA','INTERV_Q', 'PROCED']

for year, df in dataframes.items():
    dataframes[year] = df.drop(columns=[col for col in columns_to_drop if col in df.columns], errors='ignore')

df_total = pd.concat(dataframes.values(), ignore_index=True)

# %%
df_total.columns
# Out:
# Index(['PERTENENCIA_ESTABLECIMIENTO_SALUD', 'SEXO', 'GRUPO_EDAD',
#        'REGION_RESIDENCIA', 'GLOSA_REGION_RESIDENCIA', 'PREVISION',
#        'GLOSA_PREVISION', 'ANO_EGRESO', 'DIAG1', 'DIAG2', 'DIAS_ESTADA',
#        'CONDICION_EGRESO', 'PERTENENCIA_ESTABLECIMIENTO_SALU'],
#       dtype='object')

# %%
df_total['SEXO'].unique()
# Out:
# array(['HOMBRE', 'MUJER', '*', 'DESCONOCIDO', 'INTERSEX (INDETERMINDADO)'],
#       dtype=object)

# %%
df_total = pd.read_csv("egresos_total.csv", sep=",", encoding="latin-1")
df_total
# Out:
# C:\Users\Siwidiwi\AppData\Local\Temp\ipykernel_7808\3487605325.py:1: DtypeWarning: Columns (0,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_total = pd.read_csv("egresos_total.csv", sep=",", encoding="latin-1")
#                          PERTENENCIA_ESTABLECIMIENTO_SALUD    SEXO  \
# 0        No Pertenecientes al Sistema Nacional de Servi...  HOMBRE
# 1        No Pertenecientes al Sistema Nacional de Servi...  HOMBRE
# 2        No Pertenecientes al Sistema Nacional de Servi...  HOMBRE
# 3        No Pertenecientes al Sistema Nacional de Servi...  HOMBRE
# 4        No Pertenecientes al Sistema Nacional de Servi...  HOMBRE
# ...                                                    ...     ...
# 3030176  Pertenecientes al Sistema Nacional de Servicio...  HOMBRE
# 3030177  Pertenecientes al Sistema Nacional de Servicio...   MUJER
# 3030178  Pertenecientes al Sistema Nacional de Servicio...   MUJER
# ...

# %%
# Filtrar 'SEXO' para dejar solo 'HOMBRE' y 'MUJER'
df_total = df_total[df_total['SEXO'].isin(['HOMBRE', 'MUJER'])]

# Limpiar 'CONDICION_EGRESO': eliminar '*', convertir '1' y '2' a números
df_total = df_total[df_total['CONDICION_EGRESO'].isin(['1', '2', 1, 2])]
 
# Convertir todos los valores en 'CONDICION_EGRESO' a numéricos
df_total['CONDICION_EGRESO'] = pd.to_numeric(df_total['CONDICION_EGRESO'])

# %%
df_total['CONDICION_EGRESO'].unique()
# Out:
# array([1, 2])

# %%
# Eliminar filas donde 'CONDICION_EGRESO' sea NaN
df_total = df_total.dropna(subset=['CONDICION_EGRESO'])
df_total = df_total.dropna(subset=['DIAG1'])
df_total = df_total.dropna(subset=['DIAG2'])

# %%
# Convertir 'CONDICION_EGRESO' a categórico con etiquetas descriptivas
df_total['CONDICION_EGRESO'] = df_total['CONDICION_EGRESO'].map({1: 'Vivo', 2: 'Muerto'})

# Verificar que las columnas importantes tengan valores adecuados
print(df_total['CONDICION_EGRESO'].value_counts())
print(df_total['SEXO'].value_counts())
print(df_total['GRUPO_EDAD'].unique())
# Out:
# CONDICION_EGRESO
# Vivo      31098735
# Muerto      634203
# Name: count, dtype: int64
# SEXO
# MUJER     19197705
# HOMBRE    12535233
# Name: count, dtype: int64
# ['1 a 9' '10 a 19' '20 a 29' '30 a 39' '40 a 49' '50 a 59' '60 a 69'
#  '70 a 79' '80 a 89' '90 y más' 'menor de un año']

# %%
df_total['']

# %% [markdown]
# ### PROPORCION DE MORTALIDAD POR GÉNERO

# %%
# proporción de mortalidad por género
mortalidad_por_genero = df_total.groupby('SEXO')['CONDICION_EGRESO'].value_counts(normalize=True).unstack() * 100
print(mortalidad_por_genero)

import matplotlib.pyplot as plt

mortalidad_por_genero.plot(kind='bar', stacked=True, color=['skyblue', 'salmon'])
plt.title('Proporción de Mortalidad por Género')
plt.ylabel('Porcentaje')
plt.xlabel('Género')
plt.legend(title='Condición de Egreso')
plt.show()
# Out:
# CONDICION_EGRESO          1         2
# SEXO
# HOMBRE            98.952607  1.047393
# MUJER             99.063101  0.936899

# %% [markdown]
# A partir de los datos proporcionados sobre la proporción de mortalidad por género, podemos observar lo siguiente:
#
# - Hombres: La tasa de mortalidad es del 2.72% y  supervivencia es del 97.28%.
# - Mujeres: La tasa de mortalidad es del 1.53% y la supervivencia es del 98.47%.
# - Conclusión:
# La mortalidad es más alta en hombres (2.72%) en comparación con las mujeres (1.53%).
# Esto sugiere que los hombres tienen una mayor probabilidad de fallecer bajo las condiciones estudiadas, lo cual podría estar relacionado con factores biológicos, sociales o el tipo de enfermedades o causas que afectan a cada género.

# %%
mortalidad_por_edad = df_total.groupby('GRUPO_EDAD')['CONDICION_EGRESO'].value_counts(normalize=True).unstack() * 100
print(mortalidad_por_edad)
orden_grupo_edad = ['menor de un año', '1 a 9', '10 a 19', '20 a 29', '30 a 39',
                    '40 a 49', '50 a 59', '60 a 69', '70 a 79', '80 a 89', '90 y más']

# Reasignar el índice de GRUPO_EDAD con el orden especificado
mortalidad_por_edad = mortalidad_por_edad.reindex(orden_grupo_edad)
mortalidad_por_edad.plot(kind='bar', stacked=True, colormap='viridis')
plt.title('Proporción de Mortalidad por Grupo de Edad')
plt.ylabel('Porcentaje')
plt.xlabel('Grupo de Edad')
plt.legend(title='Condición de Egreso')
plt.show()
# Out:
# C:\Users\Siwidiwi\AppData\Local\Temp\ipykernel_7808\2763954341.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mortalidad_por_edad = df_total.groupby('GRUPO_EDAD')['CONDICION_EGRESO'].value_counts(normalize=True).unstack() * 100
# CONDICION_EGRESO          1         2
# GRUPO_EDAD
# menor de un año    0.000000  0.000000
# 1 a 9             99.835094  0.164906
# 10 a 19           99.649429  0.350571
# 20 a 29           99.392242  0.607758
# 30 a 39           99.398855  0.601145
# 40 a 49           99.227074  0.772926
# 50 a 59           98.974510  1.025490
# 60 a 69           98.421445  1.578555
# 70 a 79           97.481128  2.518872
# 80 a 89           96.327072  3.672928
# 90 y más           0.000000  0.000000

# %%
mortalidad_por_edad
# Out:
# CONDICION_EGRESO          1         2
# GRUPO_EDAD
# 1 a 9             99.835094  0.164906
# 10 a 19           99.649429  0.350571
# 20 a 29           99.392242  0.607758
# 30 a 39           99.398855  0.601145
# 40 a 49           99.227074  0.772926
# 50 a 59           98.974510  1.025490
# 60 a 69           98.421445  1.578555
# 70 a 79           97.481128  2.518872
# 80 a 89           96.327072  3.672928
# 90 y mÃ¡s         94.366267  5.633733
# menor de un aÃ±o  99.616411  0.383589

# %%
#matriz de corre

# %% [markdown]
# - Grupos de menor edad:
#
# Los grupos de 1 a 9 años, 10 a 19 años, y 20 a 29 años presentan tasas de mortalidad muy bajas (entre 0.18% y 0.21%), con supervivencias superiores al 99.7%.
# En los menores de un año, la mortalidad es del 1.10%, más alta que en los niños mayores.
#
# - Adultos jóvenes y adultos de mediana edad:
#
# La mortalidad empieza a aumentar en el grupo de 30 a 39 años (0.35%) y sigue incrementándose de manera progresiva en los grupos de 40 a 49 años (0.98%) y 50 a 59 años (2.05%).
#
# - Adultos mayores:
#
# A partir de los 60 años, se observa un aumento marcado de la mortalidad:
# 60 a 69 años: 3.55%
# 70 a 79 años: 5.85%
# 80 a 89 años: 9.80%
# 90 años y más: 14.98%
# Conclusiones:
# Aumento de mortalidad con la edad:
#
# Existe una relación clara entre el aumento de la edad y la mortalidad, especialmente significativa a partir de los 60 años, y se intensifica considerablemente en los adultos mayores (80 años y más).
# Mayor vulnerabilidad en los extremos de la vida:
#
# Aunque la mortalidad en los niños (1 a 9 años) es baja, el grupo de menores de un año tiene una mortalidad mayor que otros grupos jóvenes (1.10%), probablemente debido a su vulnerabilidad fisiológica y la mayor susceptibilidad a enfermedades graves.
# Prioridades de intervención:
#
# Los grupos mayores de 60 años deberían ser una prioridad para políticas de salud pública, prevención y acceso a tratamientos debido a su mayor riesgo de fallecimiento. También es importante prestar atención a los menores de un año para mitigar las causas de mortalidad en este grupo.

# %%
import seaborn as sns
import pandas as pd

# Crear tabla cruzada
tabla_cruzada = pd.crosstab(df_total['SEXO'], df_total['CONDICION_EGRESO'])
print(tabla_cruzada)

# Test de Chi-cuadrado
from scipy.stats import chi2_contingency

chi2, p, dof, ex = chi2_contingency(tabla_cruzada)
print(f"Chi-cuadrado: {chi2}, p-valor: {p}")
# Out:
# CONDICION_EGRESO        1      2
# SEXO
# HOMBRE            1896117  20070
# MUJER             1103557  10437
# Chi-cuadrado: 86.18477820941024, p-valor: 1.6388428149354617e-20

# %%
mortalidad_por_edad = df_total.groupby('GRUPO_EDAD')['CONDICION_EGRESO'].value_counts(normalize=True).unstack() * 100
print(mortalidad_por_edad)
orden_grupo_edad = ['menor de un año', '1 a 9', '10 a 19', '20 a 29', '30 a 39',
                    '40 a 49', '50 a 59', '60 a 69', '70 a 79', '80 a 89', '90 y más']

# Reasignar el índice de GRUPO_EDAD con el orden especificado
mortalidad_por_edad = mortalidad_por_edad.reindex(orden_grupo_edad)
mortalidad_por_edad.plot(kind='bar', stacked=True, colormap='viridis')
plt.title('Proporción de Mortalidad por Grupo de Edad')
plt.ylabel('Porcentaje')
plt.xlabel('Grupo de Edad')
plt.legend(title='Condición de Egreso')
plt.show()

# %%
# Proporción de mortalidad por género y grupo de edad
mortalidad_detallada = df_total.groupby(['GRUPO_EDAD', 'SEXO'])['CONDICION_EGRESO'].value_counts(normalize=True).unstack() * 100
print(mortalidad_detallada)
# Gráfico de barras apiladas
mortalidad_detallada.unstack().plot(kind='bar', stacked=True, figsize=(10, 6), colormap='coolwarm')
plt.title('Proporción de Mortalidad por Género y Grupo de Edad')
plt.ylabel('Porcentaje')
plt.xlabel('Grupo de Edad y Género')
plt.legend(title='Condición de Egreso')
plt.show()
# Out:
# C:\Users\Siwidiwi\AppData\Local\Temp\ipykernel_7808\4267703174.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mortalidad_detallada = df_total.groupby(['GRUPO_EDAD', 'SEXO'])['CONDICION_EGRESO'].value_counts(normalize=True).unstack() * 100
# CONDICION_EGRESO                1         2
# GRUPO_EDAD      SEXO
# menor de un año HOMBRE   0.000000  0.000000
#                 MUJER    0.000000  0.000000
# 1 a 9           HOMBRE  99.840456  0.159544
#                 MUJER   99.826962  0.173038
# 10 a 19         HOMBRE  99.618408  0.381592
#                 MUJER   99.712236  0.287764
# 20 a 29         HOMBRE  99.339432  0.660568
#                 MUJER   99.562488  0.437512
# 30 a 39         HOMBRE  99.320259  0.679741
#                 MUJER   99.627128  0.372872
# ...

# %%
#a dummy 
orden_grupo_edad = ['menor de un año', '1 a 9', '10 a 19', '20 a 29', '30 a 39',
                    '40 a 49', '50 a 59', '60 a 69', '70 a 79', '80 a 89', '90 y más']

# %%
mortalidad_detallada
# Out:
# CONDICION_EGRESO                1         2
# GRUPO_EDAD      SEXO
# menor de un año HOMBRE   0.000000  0.000000
#                 MUJER    0.000000  0.000000
# 1 a 9           HOMBRE  99.840456  0.159544
#                 MUJER   99.826962  0.173038
# 10 a 19         HOMBRE  99.618408  0.381592
#                 MUJER   99.712236  0.287764
# 20 a 29         HOMBRE  99.339432  0.660568
#                 MUJER   99.562488  0.437512
# 30 a 39         HOMBRE  99.320259  0.679741
#                 MUJER   99.627128  0.372872
# 40 a 49         HOMBRE  99.085112  0.914888
#                 MUJER   99.555128  0.444872
# 50 a 59         HOMBRE  98.684186  1.315814
#                 MUJER   99.435556  0.564444
# 60 a 69         HOMBRE  97.870256  2.129744
#                 MUJER   99.071752  0.928248
# 70 a 79         HOMBRE  96.340130  3.659870
#                 MUJER   98.297263  1.702737
# 80 a 89         HOMBRE  94.472374  5.527626
#                 MUJER   97.071217  2.928783
# ...

# %%
mortalidad_detallada['COND']
# Out:
# Index([1, 2], dtype='int64', name='CONDICION_EGRESO')

# %%
# Asegurarte de que el índice es plano para trabajar con columnas
mortalidad_detallada_reset = mortalidad_detallada.reset_index()

# Convertir GRUPO_EDAD a categorías numéricas ordenadas
mortalidad_detallada_reset['GRUPO_EDAD'] = pd.Categorical(
    mortalidad_detallada_reset['GRUPO_EDAD'],
    categories=orden_grupo_edad,
    ordered=True
)

# Crear variables dummies para GRUPO_EDAD y SEXO
dummies = pd.get_dummies(mortalidad_detallada_reset[['GRUPO_EDAD', 'SEXO']], drop_first=False)

# Combinar las dummies con el resto del DataFrame
mortalidad_encoded = pd.concat([mortalidad_detallada_reset.drop(columns=['GRUPO_EDAD', 'SEXO']), dummies], axis=1)

# Calcular la matriz de correlación
correlation_matrix = mortalidad_encoded.corr()

# Imprimir la matriz de correlación
print("Matriz de correlación:")
print(correlation_matrix)
# Out:
# Matriz de correlación:
#                                    1         2  GRUPO_EDAD_menor de un año  \
# 1                           1.000000  0.334931               -6.704490e-01
# 2                           0.334931  1.000000               -2.455849e-01
# GRUPO_EDAD_menor de un año -0.670449 -0.245585                1.000000e+00
# GRUPO_EDAD_1 a 9            0.158340 -0.206975               -1.000000e-01
# GRUPO_EDAD_10 a 19          0.156942 -0.167878               -1.000000e-01
# GRUPO_EDAD_20 a 29          0.155163 -0.118106               -1.000000e-01
# GRUPO_EDAD_30 a 39          0.155352 -0.123384               -1.000000e-01
# GRUPO_EDAD_40 a 49          0.154077 -0.087727               -1.000000e-01
# GRUPO_EDAD_50 a 59          0.151916 -0.027301               -1.000000e-01
# GRUPO_EDAD_60 a 69          0.147027  0.109425               -1.000000e-01
# GRUPO_EDAD_70 a 79          0.137461  0.376974               -1.000000e-01
# ...

# %%
correlation_matrix
# Out:
#                                    1         2  GRUPO_EDAD_menor de un año  \
# 1                           1.000000  0.334931               -6.704490e-01
# 2                           0.334931  1.000000               -2.455849e-01
# GRUPO_EDAD_menor de un año -0.670449 -0.245585                1.000000e+00
# GRUPO_EDAD_1 a 9            0.158340 -0.206975               -1.000000e-01
# GRUPO_EDAD_10 a 19          0.156942 -0.167878               -1.000000e-01
# GRUPO_EDAD_20 a 29          0.155163 -0.118106               -1.000000e-01
# GRUPO_EDAD_30 a 39          0.155352 -0.123384               -1.000000e-01
# GRUPO_EDAD_40 a 49          0.154077 -0.087727               -1.000000e-01
# GRUPO_EDAD_50 a 59          0.151916 -0.027301               -1.000000e-01
# GRUPO_EDAD_60 a 69          0.147027  0.109425               -1.000000e-01
# GRUPO_EDAD_70 a 79          0.137461  0.376974               -1.000000e-01
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Crear un mapa de calor de la matriz de correlación
plt.figure(figsize=(12, 8))  # Tamaño de la figura
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)

# Títulos y etiquetas
plt.title("Mapa de calor de la matriz de correlación")
plt.show()

# %% [markdown]
# Tendencias de mortalidad por edad: La mortalidad aumenta con la edad, como se esperaba, y los más jóvenes tienen una probabilidad mucho más alta de sobrevivir en comparación con los más viejos.
# Impacto del sexo: Aunque el sexo influye en la mortalidad, parece que el factor más importante es el grupo de edad, con una distinción entre hombres y mujeres en algunas categorías.

# %% [markdown]
#         1. Proporciones por género y grupo de edad:
#         La tabla presenta la proporción de mortalidad (muerto) y la proporción de sobrevivencia (vivo) para hombres y mujeres, distribuidos por grupos de edad. La proporción de mortalidad está expresada en porcentaje para cada grupo, lo que facilita la comparación entre categorías.
#
#         2. Tendencias generales:
#         Jóvenes (0-9 años y 10-19 años):
#
#         Las tasas de mortalidad son generalmente bajas tanto para hombres como para mujeres en estos grupos de edad. La proporción de sobrevivientes es superior al 99%.
#         La mortalidad es ligeramente mayor en hombres en todos los grupos, pero las diferencias no son grandes.
#         Adultos jóvenes (20-39 años):
#
#         Aquí las tasas de mortalidad empiezan a aumentar, especialmente en hombres, con una proporción que supera el 0.6% en el grupo de 20-29 años y continúa incrementándose en grupos de mayor edad.
#         Para las mujeres, la mortalidad sigue siendo baja, pero también comienza a aumentar ligeramente en comparación con los grupos más jóvenes.
#         Adultos de mediana edad (40-59 años):
#
#         A medida que las personas envejecen, la proporción de mortalidad aumenta considerablemente.
#         En este grupo, las tasas de mortalidad en hombres superan el 1%, siendo más pronunciada en hombres mayores de 50 años. Las mujeres también muestran un aumento en la mortalidad, pero las tasas siguen siendo más bajas en comparación con los hombres.
#         Adultos mayores (60 años en adelante):
#
#         Las tasas de mortalidad aumentan significativamente, con las diferencias de género más evidentes en los grupos de edad de 60-69 años y 70-79 años. En estos grupos, la mortalidad en hombres es notablemente más alta, alcanzando hasta 6.4% en hombres de 70-79 años.
#         En los grupos de 80-89 años y 90 y más, las tasas de mortalidad son muy altas en ambos géneros, pero los hombres siguen mostrando mayores proporciones de mortalidad que las mujeres.
#         Menor de un año:
#
#         La mortalidad para los niños menores de un año es relativamente baja, con proporciones cercanas al 1%, aunque similar para hombres y mujeres.
#         3. Análisis de género:
#         En la mayoría de los grupos de edad, los hombres tienden a tener una mayor proporción de mortalidad que las mujeres, especialmente en los grupos de mayor edad, como 60 a 69 años, 70 a 79 años y 80 a 89 años. Esta tendencia puede estar relacionada con diferencias biológicas, acceso a la salud, estilos de vida, o factores socioculturales que influyen en la mortalidad.
#
#         4. Tendencias según la edad:
#         A medida que la edad aumenta, la mortalidad también aumenta en ambos géneros, lo que refleja la mayor vulnerabilidad asociada con la edad avanzada.
#         En los grupos más jóvenes, las tasas de mortalidad son muy bajas, mientras que en los grupos de 60 años o más, las tasas se disparan, lo que es esperado debido a las condiciones de salud asociadas con el envejecimiento.
#         5. Posibles factores a explorar:
#         Condiciones de salud prevalentes: En los adultos mayores, las enfermedades crónicas y condiciones relacionadas con la vejez, como enfermedades cardiovasculares, cáncer, diabetes, entre otras, podrían contribuir a un aumento de la mortalidad.
#         Estilos de vida y factores de riesgo: El comportamiento de riesgo, como el consumo de tabaco, alcohol, y la falta de actividad física, podría ser un factor importante en la mayor mortalidad en hombres.
#         Acceso a atención médica: El acceso desigual a servicios de salud de calidad podría influir en las tasas de mortalidad, especialmente en los grupos de edad más avanzada.

# %%
# Proporción de mortalidad por región
mortalidad_por_region = df_total.groupby('REGION_RESIDENCIA')['CONDICION_EGRESO'].value_counts(normalize=True).unstack() * 100
print(mortalidad_por_region)

# Gráfico de barras
mortalidad_por_region.plot(kind='bar', stacked=True, colormap='plasma')
plt.title('Proporción de Mortalidad por Región')
plt.ylabel('Porcentaje')
plt.xlabel('Región')
plt.legend(title='Condición de Egreso')
plt.show()
# Out:
# CONDICION_EGRESO           1         2
# REGION_RESIDENCIA
# 1                  98.904257  1.095743
# 2                  99.344624  0.655376
# 3                  99.352485  0.647515
# 4                  99.060690  0.939310
# 5                  98.855678  1.144322
# 6                  99.086275  0.913725
# 7                  99.018682  0.981318
# 8                  99.263919  0.736081
# 9                  99.289013  0.710987
# 10                 99.030533  0.969467
# 11                 99.384703  0.615297
# 12                 99.282982  0.717018
# 13                 98.754031  1.245969
# 14                 99.286469  0.713531
# 15                 99.198915  0.801085
# 16                 98.898917  1.101083

# %%
# Aplanar el dataframe con reset_index
mortalidad_por_region
# Out:
# CONDICION_EGRESO  REGION_RESIDENCIA          1         2
# 0                                 1  98.904257  1.095743
# 1                                 2  99.344624  0.655376
# 2                                 3  99.352485  0.647515
# 3                                 4  99.060690  0.939310
# 4                                 5  98.855678  1.144322
# 5                                 6  99.086275  0.913725
# 6                                 7  99.018682  0.981318
# 7                                 8  99.263919  0.736081
# 8                                 9  99.289013  0.710987
# 9                                10  99.030533  0.969467
# 10                               11  99.384703  0.615297
# 11                               12  99.282982  0.717018
# 12                               13  98.754031  1.245969
# 13                               14  99.286469  0.713531
# 14                               15  99.198915  0.801085
# ...

# %% [markdown]
#         Análisis de la Proporción de Mortalidad por Región de Residencia:
#         El conjunto de datos muestra las proporciones de mortalidad y supervivencia por región de residencia. Al igual que en el análisis por grupo de edad y género, podemos observar algunas tendencias clave:
#
#         1. Proporción de Mortalidad:
#         Las proporciones de mortalidad varían ligeramente entre las diferentes regiones, pero en general, se encuentran en el rango de 1.3% a 2.6%.
#         Las regiones con las proporciones de mortalidad más bajas son la región 02 (1.30%) y la región 10 (1.78%).
#         Las regiones con las proporciones más altas son la región 16 (2.58%) y la región 05 (2.35%).
#         La variabilidad en las tasas de mortalidad entre las regiones es moderada, con una diferencia de alrededor de 1% entre las regiones de mortalidad más alta y más baja.
#         2. Proporción de Supervivencia:
#         La proporción de supervivencia es consistentemente alta en todas las regiones, variando entre 97.4% y 98.7%, lo que indica que la mayoría de las personas en cada región sobreviven.
#         Las regiones con mayores tasas de supervivencia son la región 10 (98.22%) y la región 11 (98.50%).
#         Las regiones con las menores tasas de supervivencia son la región 16 (97.42%) y la región 05 (97.65%).
#         3. Análisis comparativo:
#         Las regiones con mayor mortalidad (por ejemplo, la región 16) también presentan una ligera disminución en la proporción de supervivencia. Sin embargo, en todas las regiones, las tasas de supervivencia siguen siendo significativamente más altas que las de mortalidad.
#         Las diferencias entre las regiones no son extremadamente grandes, lo que sugiere que, en general, las tasas de mortalidad y supervivencia son bastante uniformes en las diferentes áreas de residencia.
#         4. Posibles factores a considerar:
#         Condiciones de salud regionales: Las diferencias en las tasas de mortalidad entre regiones podrían estar asociadas con la disponibilidad y calidad de los servicios de salud en cada área. Regiones con mayores tasas de mortalidad podrían tener menos acceso a atención médica o a servicios de salud especializados.
#         Factores socioeconómicos y ambientales: Factores como el nivel socioeconómico, la educación, las condiciones de vivienda, y la exposición a factores ambientales también podrían influir en las tasas de mortalidad.
#         Estilos de vida y factores de riesgo: Diferencias en los estilos de vida, como hábitos alimenticios, ejercicio, consumo de tabaco o alcohol, entre otras, también podrían jugar un papel importante en las variaciones observadas.

# %% [markdown]
#     Región 01: Arica y Parinacota
#     Región 02: Tarapacá
#     Región 03: Antofagasta
#     Región 04: Atacama
#     Región 05: Coquimbo
#     Región 06: Valparaíso
#     Región 07: O'Higgins
#     Región 08: Maule
#     Región 09: Ñuble
#     Región 10: Biobío
#     Región 11: La Araucanía
#     Región 12: Los Ríos
#     Región 13: Los Lagos
#     Región 14: Aysén del General Carlos Ibáñez del Campo
#     Región 15: Magallanes y de la Antártica Chilena
#     Región 16: Metropolitana de Santiago

# %%
#matrix
