# %%
import pandas as pd
import requests
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.max_colwidth', None)

# %%
pd.set_option('display.max_columns', None)

# Para mostrar todas las filas
pd.set_option('display.max_rows', 30)

# %%
defunciones= pd.read_csv("EGRE_DATOS_ABIERTOS_2020\DEFUNCIONES_FUENTE_DEIS_1990_2021_CIFRAS_OFICIALES.csv",sep=";",encoding="latin-1" )
columnas_filtro = [
    'AÑO',
    'FECHA_DEF',
    'SEXO_NOMBRE',
    'EDAD_TIPO',
    'EDAD_CANT',
    'COD_COMUNA',
    'COMUNA',
    'NOMBRE_REGION',
    'DIAG1',
    'CAPITULO_DIAG1',
    'DIAG2',
    'LUGAR_DEFUNCION'
]
defuncion_nodupli = defunciones.drop_duplicates(subset=columnas_filtro)
defuncion_nodupli.info()
# Out:
# C:\Users\Unidad Academica IMC\AppData\Local\Temp\ipykernel_8696\3876156362.py:1: DtypeWarning: Columns (9,10,11,12,13,14,15,16,18,19,20,21,22,23,24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   defunciones= pd.read_csv("EGRE_DATOS_ABIERTOS_2020\DEFUNCIONES_FUENTE_DEIS_1990_2021_CIFRAS_OFICIALES.csv",sep=";",encoding="latin-1" )
# <class 'pandas.core.frame.DataFrame'>
# Index: 2921723 entries, 0 to 2923255
# Data columns (total 27 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   AÑO                        int64
#  1   FECHA_DEF                  object
#  2   SEXO_NOMBRE                object
#  3   EDAD_TIPO                  float64
#  4   EDAD_CANT                  int64
#  5   COD_COMUNA                 int64
#  6   COMUNA                     object
#  7   NOMBRE_REGION              object
#  8   DIAG1                      object
#  9   CAPITULO_DIAG1             object
# ...

# %%
lista = []

# %%
nombres = ["defuncion_nodupli_0_a_4", "defuncion_nodupli_4_a_12", "defuncion_nodupli_12_a_19", "defuncion_nodupli_19_a_40", "defuncion_nodupli_40_a_60", "defuncion_nodupli_60_a_80", "defuncion_nodupli_80_plus"]

# %%
defuncion_nodupli_0_a_4 = defuncion_nodupli[(defuncion_nodupli["EDAD_TIPO"].isin([4,3,2])) | (defuncion_nodupli["EDAD_CANT"] < 4)]
lista.append(defuncion_nodupli_0_a_4)
defuncion_nodupli_0_a_4
# Out:
#           AÑO   FECHA_DEF SEXO_NOMBRE  EDAD_TIPO  EDAD_CANT  COD_COMUNA  \
# 42       1996  1996-12-19       Mujer        1.0          1        9102
# 43       1995  1995-12-17      Hombre        1.0          1        9101
# 44       1996  1996-12-19      Hombre        1.0          1       13114
# 45       1994  1994-06-22      Hombre        4.0          1        7101
# 63       1996  1996-12-24      Hombre        4.0          1        8306
# ...       ...         ...         ...        ...        ...         ...
# 2900714  2021  2021-01-25       Mujer        4.0          1       16206
# 2900715  2021  2021-01-30      Hombre        3.0          4       13602
# 2900716  2021  2021-01-31      Hombre        4.0          3       13401
# 2900717  2021  2021-02-04       Mujer        4.0         13       13119
# 2900718  2021  2021-02-06       Mujer        4.0          2        5703
#
#                COMUNA              NOMBRE_REGION DIAG1 CAPITULO_DIAG1  \
# ...

# %%
defuncion_nodupli_4_a_12 = defuncion_nodupli[(defuncion_nodupli["EDAD_TIPO"] == 1) & (defuncion_nodupli["EDAD_CANT"] >= 4) & (defuncion_nodupli["EDAD_CANT"] < 12)]
lista.append(defuncion_nodupli_4_a_12)
defuncion_nodupli_4_a_12
# Out:
#           AÑO   FECHA_DEF SEXO_NOMBRE  EDAD_TIPO  EDAD_CANT  COD_COMUNA  \
# 6        1996  1996-03-13       Mujer        1.0          7        6301
# 51       1996  1996-02-18      Hombre        1.0          7        6301
# 68       1996  1996-12-24      Hombre        1.0         10       10102
# 145      1995  1995-01-04      Hombre        1.0          8        8110
# 161      1994  1994-07-07      Hombre        1.0          8        8101
# ...       ...         ...         ...        ...        ...         ...
# 2900591  2021  2021-12-12      Hombre        1.0          6       10109
# 2900602  2021  2021-09-19      Hombre        1.0          5       13403
# 2900603  2021  2021-10-28       Mujer        1.0          5       13119
# 2900707  2021  2021-02-28       Mujer        1.0          5       13107
# 2900709  2021  2021-10-14       Mujer        1.0          5       13201
#
#                   COMUNA                NOMBRE_REGION DIAG1 CAPITULO_DIAG1  \
# ...

# %%
defuncion_nodupli_12_a_19 = defuncion_nodupli[(defuncion_nodupli["EDAD_TIPO"] == 1) & (defuncion_nodupli["EDAD_CANT"] >= 12) & (defuncion_nodupli["EDAD_CANT"] < 19)]
lista.append(defuncion_nodupli_12_a_19)
defuncion_nodupli_12_a_19
# Out:
#           AÑO   FECHA_DEF SEXO_NOMBRE  EDAD_TIPO  EDAD_CANT  COD_COMUNA  \
# 0        1994  1994-10-22      Hombre        1.0         17        8304
# 12       1995  1995-12-30      Hombre        1.0         16        5503
# 16       1995  1995-02-16      Hombre        1.0         17        5301
# 24       1993  1993-06-13      Hombre        1.0         17        5803
# 25       1994  1994-09-24       Mujer        1.0         14        8110
# ...       ...         ...         ...        ...        ...         ...
# 2895335  2021  2021-03-22      Hombre        1.0         18       13103
# 2895342  2021  2021-08-17       Mujer        1.0         12        1107
# 2895980  2021  2021-01-02       Mujer        1.0         18       15101
# 2896331  2021  2021-01-28       Mujer        1.0         18       13109
# 2900856  2021  2021-12-29      Hombre        1.0         17       13123
#
#                 COMUNA              NOMBRE_REGION DIAG1 CAPITULO_DIAG1  \
# ...

# %%
defuncion_nodupli_19_a_40 = defuncion_nodupli[(defuncion_nodupli["EDAD_TIPO"] == 1) & (defuncion_nodupli["EDAD_CANT"] >= 19) & (defuncion_nodupli["EDAD_CANT"] < 40)]
lista.append(defuncion_nodupli_19_a_40) 
defuncion_nodupli_19_a_40
# Out:
#           AÑO   FECHA_DEF SEXO_NOMBRE  EDAD_TIPO  EDAD_CANT  COD_COMUNA  \
# 3        1995  1995-08-31      Hombre        1.0         35        8101
# 4        1995  1995-09-11      Hombre        1.0         36        7301
# 11       1995  1995-12-01      Hombre        1.0         22       15101
# 15       1995  1995-01-16      Hombre        1.0         34        7301
# 18       1995  1995-03-24      Hombre        1.0         38       13105
# ...       ...         ...         ...        ...        ...         ...
# 2905543  2021  2021-10-24      Hombre        1.0         36        8112
# 2905615  2021  2021-04-07       Mujer        1.0         37       13604
# 2905616  2021  2021-05-10       Mujer        1.0         35        7101
# 2905628  2021  2021-12-15       Mujer        1.0         24       13119
# 2908147  2021  2021-02-24      Hombre        1.0         23        5301
#
#                 COMUNA              NOMBRE_REGION DIAG1 CAPITULO_DIAG1  \
# ...

# %%
defuncion_nodupli_40_a_60 = defuncion_nodupli[(defuncion_nodupli["EDAD_TIPO"] == 1) & (defuncion_nodupli["EDAD_CANT"] >= 40) & (defuncion_nodupli["EDAD_CANT"] < 60)]
lista.append(defuncion_nodupli_40_a_60)
defuncion_nodupli_40_a_60
# Out:
#           AÑO   FECHA_DEF SEXO_NOMBRE  EDAD_TIPO  EDAD_CANT  COD_COMUNA  \
# 1        1995  1995-04-15      Hombre        1.0         50        6115
# 2        1995  1995-04-09      Hombre        1.0         50       13108
# 5        1995  1995-08-08      Hombre        1.0         50        6115
# 8        1995  1995-01-10      Hombre        1.0         44        6115
# 9        1995  1995-08-31      Hombre        1.0         40        6101
# ...       ...         ...         ...        ...        ...         ...
# 2903990  2021  2021-10-16      Hombre        1.0         42       10208
# 2904688  2021  2021-01-12      Hombre        1.0         44       13201
# 2904704  2021  2021-06-02      Hombre        1.0         48       13112
# 2905252  2021  2021-09-14      Hombre        1.0         47       13605
# 2905732  2021  2021-05-27      Hombre        1.0         40       16107
#
#                 COMUNA                NOMBRE_REGION DIAG1 CAPITULO_DIAG1  \
# ...

# %%
defuncion_nodupli_60_a_80 = defuncion_nodupli[(defuncion_nodupli["EDAD_TIPO"] == 1) & (defuncion_nodupli["EDAD_CANT"] >= 60) & (defuncion_nodupli["EDAD_CANT"] < 80)]
lista.append(defuncion_nodupli_60_a_80)
defuncion_nodupli_60_a_80
# Out:
#           AÑO   FECHA_DEF SEXO_NOMBRE  EDAD_TIPO  EDAD_CANT  COD_COMUNA  \
# 7        1994         NaN      Hombre        1.0         70        7304
# 19       1995  1995-06-03      Hombre        1.0         68        5503
# 30       1994         NaN      Hombre        1.0         65        8101
# 32       1995  1995-05-21       Mujer        1.0         77       13128
# 34       1995  1995-06-30      Hombre        1.0         65        7401
# ...       ...         ...         ...        ...        ...         ...
# 2923098  2021  2021-08-07      Hombre        1.0         76        9101
# 2923120  2021  2021-02-09       Mujer        1.0         75        6106
# 2923164  2021  2021-02-24      Hombre        1.0         79        7301
# 2923208  2021  2021-09-17       Mujer        1.0         79        6203
# 2923219  2021  2021-01-22      Hombre        1.0         79        4102
#
#              COMUNA                NOMBRE_REGION DIAG1 CAPITULO_DIAG1  \
# ...

# %%
defuncion_nodupli_80_plus = defuncion_nodupli[(defuncion_nodupli["EDAD_TIPO"] == 1) & (defuncion_nodupli["EDAD_CANT"] >= 80)]
lista.append(defuncion_nodupli_80_plus)
defuncion_nodupli_80_plus
# Out:
#           AÑO   FECHA_DEF SEXO_NOMBRE  EDAD_TIPO  EDAD_CANT  COD_COMUNA  \
# 13       1996  1996-05-15      Hombre        1.0         82        9111
# 20       1995  1995-05-31      Hombre        1.0         99       10101
# 97       1995  1995-08-10      Hombre        1.0         84        8202
# 149      1994  1994-01-01      Hombre        1.0         83        7103
# 265      1996  1996-10-21      Hombre        1.0         97        8203
# ...       ...         ...         ...        ...        ...         ...
# 2923251  2021  2021-11-07       Mujer        1.0         93       13115
# 2923252  2021  2021-10-09       Mujer        1.0         88        5402
# 2923253  2021  2021-11-17      Hombre        1.0         80       13104
# 2923254  2021  2021-02-03      Hombre        1.0         80       13122
# 2923255  2021  2021-01-26       Mujer        1.0         87       13127
#
#                  COMUNA              NOMBRE_REGION DIAG1 CAPITULO_DIAG1  \
# ...

# %%
lista_tops_edades = []
for i in range (len(lista)):
    df = lista[i].groupby("DIAG1").size().reset_index().sort_values(by=0, ascending=False).reset_index()
    print(nombres[i])
    df.name = nombres[i]
    summon = df.head(5)
    summon.name = nombres[i]
    lista_tops_edades.append(summon)
# Out:
# defuncion_nodupli_0_a_4
# defuncion_nodupli_4_a_12
# defuncion_nodupli_12_a_19
# defuncion_nodupli_19_a_40
# defuncion_nodupli_40_a_60
# defuncion_nodupli_60_a_80
# defuncion_nodupli_80_plus

# %%
#Es lo mismo pero para diag2
lista_tops_edades_diag_2 = []
for i in range (len(lista)):
    df = lista[i].groupby("DIAG2").size().reset_index().sort_values(by=0, ascending=False).reset_index()
    print(nombres[i])
    df.name = nombres[i]
    summon = df.head(5)
    summon.name = nombres[i]
    lista_tops_edades_diag_2.append(summon)
# Out:
# defuncion_nodupli_0_a_4
# defuncion_nodupli_4_a_12
# defuncion_nodupli_12_a_19
# defuncion_nodupli_19_a_40
# defuncion_nodupli_40_a_60
# defuncion_nodupli_60_a_80
# defuncion_nodupli_80_plus

# %%
for i in lista_tops_edades_diag_2:
    plt.bar(i["DIAG2"], i[0])
    plt.title(i.name)
    plt.show()

# %%
fortnite_2 = defuncion_nodupli.groupby(by=["DIAG2"]).size().reset_index()

# %%
#Esto debe rseponder parcialmente la pregunta de las edades
for i in lista_tops_edades:
    plt.bar(i["DIAG1"], i[0])
    plt.title(i.name)
    plt.show()

# %%
defuncion_nodupli["MES"] = defuncion_nodupli["FECHA_DEF"].apply(lambda x: x[5:7] if type(x) != float else x)
# Out:
# C:\Users\Unidad Academica IMC\AppData\Local\Temp\ipykernel_8696\856532746.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   defuncion_nodupli["MES"] = defuncion_nodupli["FECHA_DEF"].apply(lambda x: x[5:7] if type(x) != float else x)

# %%
muertes_año_mes = defuncion_nodupli.groupby(["AÑO", "MES"]).size().reset_index()

# %%
muertes_año_mes["AÑO_MES"] = muertes_año_mes["AÑO"].apply(lambda x: str(x)[-2:]) + "-" + muertes_año_mes["MES"]

# %%
muertes_año_mes = muertes_año_mes[muertes_año_mes["AÑO"] > 2000]

# %%
plt.figure(figsize=(100, 6))

plt.xticks(fontsize=5)
plt.bar(muertes_año_mes["AÑO_MES"], muertes_año_mes[0])
# Out:
# <BarContainer object of 252 artists>

# %%
fortnite_2 = defuncion_nodupli.groupby(by=["DIAG2"]).size().reset_index()

# %%
yeah = fortnite_2.sort_values(by=0, ascending=False).head(10)

# %%
yeah
# Out:
#      DIAG2      0
# 1428  X700  21800
# 439   V093  18545
# 718   V892  13681
# 414   9889  11419
# 1373  X599  11043
# 871   W199   8804
# 1057  W748   7146
# 1437  X709   6187
# 248   911X   5881
# 1436  X708   4953

# %%
plt.bar(yeah["DIAG2"], yeah[0], color="blue") #ESTE GRAICO ES LA P1
# Out:
# <BarContainer object of 10 artists>

# %%
fortnite_2.sort_values(by=0, ascending=False)["DIAG2"].head(10).to_list()
# Out:
# ['X700',
#  'V093',
#  'V892',
#  '9889',
#  'X599',
#  'W199',
#  'W748',
#  'X709',
#  '911X',
#  'X708']

# %%
fortnite_1 = defuncion_nodupli.groupby(by=["DIAG1"]).size().reset_index()
fortnite_1
# Out:
#      DIAG1      0
# 0     0019      5
# 1     0020     89
# 2     0021      1
# 3     0029      5
# 4     0030      1
# ...    ...    ...
# 6818  T982      1
# 6819  T983     22
# 6820  U071  37579
# 6821  U072   3721
# 6822  U099     75
#
# [6823 rows x 2 columns]

# %%
fortnite_1[fortnite_1[0] == 145162.000000]
# Out:
#      DIAG1       0
# 4107  I219  145162

# %%
df_contado = defuncion_nodupli.groupby('AÑO').size().reset_index(name='conteo')
df_contado
# Out:
#      AÑO  conteo
# 0   1990   78379
# 1   1991   74790
# 2   1992   74034
# 3   1993   76222
# 4   1994   75411
# 5   1995   78496
# 6   1996   79077
# 7   1997   78428
# 8   1998   80216
# 9   1999   81943
# 10  2000   78789
# 11  2001   81833
# 12  2002   81062
# 13  2003   83633
# 14  2004   86119
# 15  2005   86035
# 16  2006   85603
# 17  2007   92966
# 18  2008   90134
# 19  2009   91937
# 20  2010   97825
# 21  2011   94937
# 22  2012   98678
# 23  2013   99739
# 24  2014  101925
# 25  2015  103284
# 26  2016  103995
# 27  2017  106339
# 28  2018  106768
# 29  2019  109637
# 30  2020  125970
# 31  2021  137519

# %%
egresos = pd.read_csv("EGRE_DATOS_ABIERTOS_2020\EGRE_DATOS_ABIERTOS_2020.csv", sep=";", encoding="latin-1")
egresos1 = egresos[egresos['CONDICION_EGRESO'] == 2]
egresos2 = egresos1['CONDICION_EGRESO'].value_counts().get(2, 0)
# Out:
# C:\Users\Unidad Academica IMC\AppData\Local\Temp\ipykernel_8696\2135484550.py:1: DtypeWarning: Columns (7,9,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   egresos = pd.read_csv("EGRE_DATOS_ABIERTOS_2020\EGRE_DATOS_ABIERTOS_2020.csv", sep=";", encoding="latin-1")

# %%
egresos
# Out:
# array([1, 2], dtype=int64)

# %%
# PACIENTES QUE SALIERON DEL HOSPITASL VIVOS DEL EGRESO

egresos = egresos[egresos['CONDICION_EGRESO'] == 1]
egresos4 = egresos['CONDICION_EGRESO'].value_counts().get(2, 0)
egresos5 = egresos[egresos['SEXO'] != '*'].reset_index(drop=True)
print(egresos3.keys())
egresos5
# Out:
# Index(['PERTENENCIA_ESTABLECIMIENTO_SALUD', 'SEXO', 'GRUPO_EDAD', 'ETNIA',
#        'GLOSA_PAIS_ORIGEN', 'COMUNA_RESIDENCIA', 'GLOSA_COMUNA_RESIDENCIA',
#        'REGION_RESIDENCIA', 'GLOSA_REGION_RESIDENCIA', 'PREVISION',
#        'GLOSA_PREVISION', 'ANO_EGRESO', 'DIAG1', 'DIAG2', 'DIAS_ESTADA',
#        'CONDICION_EGRESO', 'INTERV_Q', 'PROCED'],
#       dtype='object')
#                          PERTENENCIA_ESTABLECIMIENTO_SALUD    SEXO  \
# 0        No Pertenecientes al Sistema Nacional de Servi...  HOMBRE
# 1        No Pertenecientes al Sistema Nacional de Servi...  HOMBRE
# 2        No Pertenecientes al Sistema Nacional de Servi...  HOMBRE
# 3        No Pertenecientes al Sistema Nacional de Servi...  HOMBRE
# 4        No Pertenecientes al Sistema Nacional de Servi...  HOMBRE
# ...                                                    ...     ...
# 1251051  No Pertenecientes al Sistema Nacional de Servi...   MUJER
# 1251052  No Pertenecientes al Sistema Nacional de Servi...   MUJER
# ...

# %%
len(egresos["DIAG1"].unique())
# Out:
# 7070

# %%
egresoff = egresos3.drop_duplicates(subset=['PERTENENCIA_ESTABLECIMIENTO_SALUD','SEXO', 'COMUNA_RESIDENCIA', 'GLOSA_COMUNA_RESIDENCIA','REGION_RESIDENCIA','GLOSA_REGION_RESIDENCIA','ANO_EGRESO','DIAG1','DIAG2','GLOSA_PREVISION','DIAS_ESTADA']).reset_index(drop=True)
egresoff_na = egresoff.dropna(subset=['PERTENENCIA_ESTABLECIMIENTO_SALUD','SEXO', 'COMUNA_RESIDENCIA', 'GLOSA_COMUNA_RESIDENCIA','REGION_RESIDENCIA','GLOSA_REGION_RESIDENCIA','ANO_EGRESO','DIAG1','GLOSA_PREVISION']).reset_index(drop=True)
egresoff_na
# Out:
#                        PERTENENCIA_ESTABLECIMIENTO_SALUD    SEXO  \
# 0      Pertenecientes al Sistema Nacional de Servicio...  HOMBRE
# 1      Pertenecientes al Sistema Nacional de Servicio...  HOMBRE
# 2      Pertenecientes al Sistema Nacional de Servicio...   MUJER
# 3      Pertenecientes al Sistema Nacional de Servicio...  HOMBRE
# 4      Pertenecientes al Sistema Nacional de Servicio...  HOMBRE
# ...                                                  ...     ...
# 36267  Pertenecientes al Sistema Nacional de Servicio...  HOMBRE
# 36268  Pertenecientes al Sistema Nacional de Servicio...  HOMBRE
# 36269  Pertenecientes al Sistema Nacional de Servicio...  HOMBRE
# 36270  Pertenecientes al Sistema Nacional de Servicio...   MUJER
# 36271  Pertenecientes al Sistema Nacional de Servicio...   MUJER
#
#             GRUPO_EDAD                              ETNIA GLOSA_PAIS_ORIGEN  \
# 0                1 a 9  No se identifica con alguna etnia           Chileno
# ...

# %%
defuncion_nodupli
# Out:
#           AÑO   FECHA_DEF SEXO_NOMBRE  EDAD_TIPO  EDAD_CANT  COD_COMUNA  \
# 0        1994  1994-10-22      Hombre        1.0         17        8304
# 1        1995  1995-04-15      Hombre        1.0         50        6115
# 2        1995  1995-04-09      Hombre        1.0         50       13108
# 3        1995  1995-08-31      Hombre        1.0         35        8101
# 4        1995  1995-09-11      Hombre        1.0         36        7301
# ...       ...         ...         ...        ...        ...         ...
# 2923251  2021  2021-11-07       Mujer        1.0         93       13115
# 2923252  2021  2021-10-09       Mujer        1.0         88        5402
# 2923253  2021  2021-11-17      Hombre        1.0         80       13104
# 2923254  2021  2021-02-03      Hombre        1.0         80       13122
# 2923255  2021  2021-01-26       Mujer        1.0         87       13127
#
#                 COMUNA                NOMBRE_REGION DIAG1 CAPITULO_DIAG1  ...  \
# ...

# %%
defuncion_90s= defuncion_nodupli[(defuncion_nodupli['AÑO']>=1990) & (defuncion_nodupli['AÑO']<=1999)]
defuncion_2000= defuncion_nodupli[(defuncion_nodupli['AÑO']>=2000) & (defuncion_nodupli['AÑO']<=2009)]
defuncion_2010= defuncion_nodupli[(defuncion_nodupli['AÑO']>=2010) & (defuncion_nodupli['AÑO']<=2019)]
defuncion_2000
# Out:
#           AÑO   FECHA_DEF SEXO_NOMBRE  EDAD_TIPO  EDAD_CANT  COD_COMUNA  \
# 476      2000  2000-04-12      Hombre        1.0         50        6101
# 558      2009  2009-01-18      Hombre        1.0         17       13127
# 596      2006  2006-01-17      Hombre        1.0         50       13108
# 597      2007  2007-11-26      Hombre        1.0         54       15101
# 598      2007  2007-02-10      Hombre        1.0         15       10202
# ...       ...         ...         ...        ...        ...         ...
# 2660261  2001  2001-11-13       Mujer        4.0          1       10101
# 2660270  2000  2000-12-10      Hombre        4.0          1       13401
# 2660271  2007  2007-06-15      Hombre        2.0          4        5109
# 2660277  2009  2009-08-03       Mujer        1.0          1       10202
# 2660296  2008  2008-02-15      Hombre        3.0         15       10102
#
#                 COMUNA                NOMBRE_REGION DIAG1 CAPITULO_DIAG1  ...  \
# ...

# %%
diagnosticos_90s = {
    '410X': 'Infarto Agudo de Miocardio',
    '485X': 'Neumonía por Aspiración',
    '436X': 'Accidente Cerebrovascular No Especificado',
    '7999': 'Muerte por Causa No Especificada',
    '1519': 'Neoplasia Maligna del Estómago',
    'I219': 'Infarto Agudo de Miocardio No Especificado',
    'J180': 'Neumonía Viral No Especificada',
    '8540': 'Lesión Subaracnoidea No Especificada',
    '431X': 'Hemorragia Subaracnoidea',
    '1629': 'Neoplasia Maligna de la Tráquea, Bronquios y Pulmón'
}

# %%
value_counts_90s = defuncion_90s['DIAG1'].value_counts()
df_diag_90s = value_counts_90s.reset_index()
df_diag_90s.columns = ['DIAG1', 'Count']
df_diag_90s['DIAG1'] = df_diag_90s['DIAG1'].map(diagnosticos_90s)
df_diag_90s.head(10)
# Out:
#                                                  DIAG1  Count
# 0                           Infarto Agudo de Miocardio  37514
# 1                              Neumonía por Aspiración  29211
# 2            Accidente Cerebrovascular No Especificado  25403
# 3                     Muerte por Causa No Especificada  21438
# 4                       Neoplasia Maligna del Estómago  18184
# 5           Infarto Agudo de Miocardio No Especificado  16658
# 6                       Neumonía Viral No Especificada  11978
# 7                 Lesión Subaracnoidea No Especificada  11334
# 8                             Hemorragia Subaracnoidea  11328
# 9  Neoplasia Maligna de la Tráquea, Bronquios y Pulmón  11143

# %%
diagnosticos_2000 = {
    'I219': 'Infarto Agudo de Miocardio, No Especificado',
    'C169': 'Neoplasia Maligna del Tejido Linfático y Hematopoyético, No Especificada',
    'I64X': 'Accidente Cerebrovascular (ACV), No Especificado',
    'C349': 'Neoplasia Maligna del Sistema Respiratorio, No Especificada',
    'I251': 'Enfermedad Arterial Coronaria, Crónica',
    'J189': 'Neumonía, No Especificada',
    'F03X': 'Demencia No Especificada',
    'C61X': 'Neoplasia Maligna de la Próstata',
    'I619': 'Accidente Cerebrovascular, No Especificado',
    'T71X': 'Lesiones por Exposición a la Fría, No Especificada'
}

# %%
value_counts_2000 = defuncion_2000['DIAG1'].value_counts()
df_diag_2000 = value_counts_2000.reset_index()
df_diag_2000.columns = ['DIAG1', 'Count']
df_diag_2000['DIAG1'].head(10)
df_diag_2000['DIAG1'] = df_diag_2000['DIAG1'].map(diagnosticos_2000)
df_diag_2000.head(10)
# Out:
#                                                                       DIAG1  \
# 0                               Infarto Agudo de Miocardio, No Especificado
# 1  Neoplasia Maligna del Tejido Linfático y Hematopoyético, No Especificada
# 2                          Accidente Cerebrovascular (ACV), No Especificado
# 3               Neoplasia Maligna del Sistema Respiratorio, No Especificada
# 4                                    Enfermedad Arterial Coronaria, Crónica
# 5                                                 Neumonía, No Especificada
# 6                                                  Demencia No Especificada
# 7                                          Neoplasia Maligna de la Próstata
# 8                                Accidente Cerebrovascular, No Especificado
# 9                        Lesiones por Exposición a la Fría, No Especificada
#
#    Count
# 0  56132
# 1  29683
# 2  29205
# 3  22105
# 4  17821
# 5  16909
# 6  16588
# 7  15027
# 8  14587
# 9  14526

# %%
diagnosticos_2010 = {
    'I219': 'Infarto Agudo de Miocardio, No Especificado',
    'C169': 'Neoplasia Maligna del Tejido Linfático y Hematopoyético, No Especificada',
    'C349': 'Neoplasia Maligna del Sistema Respiratorio, No Especificada',
    'J189': 'Neumonía, No Especificada',
    'I64X': 'Accidente Cerebrovascular (ACV), No Especificado',
    'C61X': 'Neoplasia Maligna de la Próstata',
    'I10X': 'Hipertensión Esencial (Primaria)',
    'I694': 'Secuelas de Enfermedad Cerebrovascular',
    'G309': 'Trastorno Cognitivo No Especificado',
    'F03X': 'Demencia No Especificada'
}

# %%
value_counts_2010 = defuncion_2010['DIAG1'].value_counts()
df_diag_2010 = value_counts_2010.reset_index()
df_diag_2010.columns = ['DIAG1', 'Count']
df_diag_2010['DIAG1'].head(10)
df_diag_2010['DIAG1'] = df_diag_2010['DIAG1'].map(diagnosticos_2010)
df_diag_2010.head(10)
# Out:
#                                                DIAG1  Count
# 0        Infarto Agudo de Miocardio, No Especificado  59344
# 1  Neoplasia Maligna del Tejido Linfático y Hemat...  31600
# 2  Neoplasia Maligna del Sistema Respiratorio, No...  30453
# 3                          Neumonía, No Especificada  28120
# 4   Accidente Cerebrovascular (ACV), No Especificado  23365
# 5                   Neoplasia Maligna de la Próstata  20764
# 6                   Hipertensión Esencial (Primaria)  19892
# 7             Secuelas de Enfermedad Cerebrovascular  19856
# 8                Trastorno Cognitivo No Especificado  17293
# 9                           Demencia No Especificada  16612

# %%
# CONDICION_EGRESO    , LUGAR_DEFUNCION, DIAG1 , 	NOMBRE_REGION, 	EDAD_CANT, GRUPO_EDAD , 	GLOSA_COMUNA_RESIDENCIA
